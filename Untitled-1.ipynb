# %%
# Importar librerias
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.mstats import winsorize
#from google.colab import drive, files
import io

# %%
df=pd.read_csv("/Users/crist/eph2.txt", sep = ",")

# %%
df
# Out:
#       edad    sexo alfabeto               sistema_salud  \
# 0     23.0  hombre       Si  Obra social (incluye PAMI)
# 1     58.0  hombre       Si  Obra social (incluye PAMI)
# 2     27.0   mujer       Si    No paga ni le descuentan
# 3     32.0  hombre       Si    No paga ni le descuentan
# 4     65.0  hombre       Si  Obra social (incluye PAMI)
# ...    ...     ...      ...                         ...
# 3511  51.0  hombre       Si    No paga ni le descuentan
# 3512  48.0  hombre       Si  Obra social (incluye PAMI)
# 3513  35.0   mujer       Si  Obra social (incluye PAMI)
# 3514  44.0  hombre       Si    No paga ni le descuentan
# 3515  37.0  hombre       Si    No paga ni le descuentan
#
#                                       nivel_educativo ocupacion_jerarquia  \
# 0                                 Secundaria Completa            Director
# 1                     Superior Universitaria Completa       Cuenta propia
# 2                                 Secundaria Completa       Cuenta propia
# 3                               Secundaria Incompleta       Cuenta propia
# 4                                   Primaria Completa       Cuenta propia
# ...                                               ...                 ...
# 3511  Primaria Incompleta(incluye educación especial)       Cuenta propia
# 3512                              Secundaria Completa            Director
# 3513                  Superior Universitaria Completa       Cuenta propia
# 3514                            Secundaria Incompleta       Cuenta propia
# 3515                            Secundaria Incompleta       Cuenta propia
#
#       estado_civil ingreso_15k
# 0                3          no
# 1                1          si
# 2                4          no
# 3                2          no
# 4                1          no
# ...            ...         ...
# 3511             1          si
# 3512             4          si
# 3513             3          si
# 3514             1          no
# 3515             3          no
#
# [3516 rows x 8 columns]

# %%
df.loc[lambda x: x.index % 2 == 0]
# Out:
#       edad    sexo alfabeto               sistema_salud  \
# 0     23.0  hombre       Si  Obra social (incluye PAMI)
# 2     27.0   mujer       Si    No paga ni le descuentan
# 4     65.0  hombre       Si  Obra social (incluye PAMI)
# 6     40.0  hombre       No    No paga ni le descuentan
# 8     42.0  hombre       Si    No paga ni le descuentan
# ...    ...     ...      ...                         ...
# 3506  58.0  hombre       Si    No paga ni le descuentan
# 3508  43.0   mujer       Si  Obra social (incluye PAMI)
# 3510  41.0   mujer       Si  Obra social (incluye PAMI)
# 3512  48.0  hombre       Si  Obra social (incluye PAMI)
# 3514  44.0  hombre       Si    No paga ni le descuentan
#
#                                       nivel_educativo ocupacion_jerarquia  \
# 0                                 Secundaria Completa            Director
# 2                                 Secundaria Completa       Cuenta propia
# 4                                   Primaria Completa       Cuenta propia
# 6     Primaria Incompleta(incluye educación especial)       Cuenta propia
# 8                               Secundaria Incompleta       Cuenta propia
# ...                                               ...                 ...
# 3506                                Primaria Completa       Cuenta propia
# 3508                  Superior Universitaria Completa       Cuenta propia
# 3510                            Secundaria Incompleta       Cuenta propia
# 3512                              Secundaria Completa            Director
# 3514                            Secundaria Incompleta       Cuenta propia
#
#       estado_civil ingreso_15k
# 0                3          no
# 2                4          no
# 4                1          no
# 6                4          no
# 8                4          no
# ...            ...         ...
# 3506             1          no
# 3508             3          si
# 3510             2          no
# 3512             4          si
# 3514             1          no
#
# [1758 rows x 8 columns]
